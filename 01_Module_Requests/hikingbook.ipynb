# %%
import requests

cookies = {
    'PHPSESSID': 'ed7uhavupqrnroqn9i5qvui1ut',
    '_fbp': 'fb.1.1776923803853.17572396326496180',
    '_gid': 'GA1.2.892250423.1776923804',
    '_pubcid': '681a7a39-29d5-4791-abab-effb18aa2833',
    '_qg_fts': '1776923804',
    '_qg_pushrequest': 'true',
    'cf_clearance': '6WMJ47GkvT1o7IXLZbIrgndzmP1MOoyvA0ScogTYeFs-1776923804-1.2.1.1-8brzGWCITVojmtzD6gR3y5qei9CCoAr4wRglyNP9y1dzPtH3g_tjvi1_spT2KrgbGWHWTIdofQztf7b20POpzfMAcqH1rsQQE1gIHlGcFjGc5jfMW0YJylHp1nZMDrMZZifSjHqG08SDwcjqhvdTQc_K3ZojPhhd1n_1286xBCe3whhI0W1BlGi8cUIOp7zyoxy72qY44JvbTRfRsEUmt8.0_8XAwqtDQZYLSPY12wE3dOR0JlbqlQw5rcZwBfbkSCkPlReW7aYQn1pP2nvNhRrbMx9OPlUJqhVM07vuTF8rbACccWDNgFAP3b9AvdLakexIZ0pFdl5wXqFcAX2AfQ',
    '_cc_id': 'cc138183f03bd76839a3d3b6957a1c9e',
    'panoramaId_expiry': '1777010204153',
    'panoramaId': '3289e31cd680d7342b1637535317a9fb927ada17af8de30e97e7535b6095988e',
    'panoramaIdType': 'panoDevice',
    'airisTracker': 'LJSQ78Zz5GtI',
    'cto_bundle': '_TcsKl83Yk5UcFdxVFFLa2FyOWZKbE5rTjNkZm9KJTJGNUVvYlFwJTJGcGtBNm5mdnkzdFhad2k3MDVKNVNXUVlOc3JtVFNJd1lrcm9ZQWo3cU1BRzBjJTJGSkZYYiUyRkY1S1BVUVNJU1BDU2gxTVlpbkhKenlsZDFiUDIwd3ZZSGhrMlYlMkJnQmNndlpGcFAlMkZIRkVHcDR3STMlMkIwOENtMjFkZyUzRCUzRA',
    'QGUserId': '1297523504894144',
    '_qg_cm': '2',
    'aiq_cs_5a937136420cfdf368a8': '[%22https:%22%2C%22biji.co%22%2C%22hiking%22%2C[[%22hiking%22%2C%22g%22]]]',
    '__htid': '3d4bd736-f15a-4d19-9a2e-2baca82e8005',
    '_ht_em': '1',
    'pacid': 'pp.1.200031341.1774422308993',
    'AviviD_uuid': 'b1096f9b-0b8a-4fcf-b55a-fe98fd32666c',
    'webuserid': '0bd73413-5f7c-4803-329b-ec4883166633',
    'AviviD_loadscript_log': '1',
    'AviviD_uuid': 'b1096f9b-0b8a-4fcf-b55a-fe98fd32666c',
    'uuid': 'b1096f9b-0b8a-4fcf-b55a-fe98fd32666c',
    '__gads': 'ID=c947f2a54e7c9261:T=1776923810:RT=1776923810:S=ALNI_MayLFCRtpwJFNhN_Mqh7_mCDXIDoA',
    '__gpi': 'UID=000013e11a4a1c9e:T=1776923810:RT=1776923810:S=ALNI_MZ6mDNPWHOxOvUlcv0ia2p8p50EaA',
    '__eoi': 'ID=d94c2f2afa995ab0:T=1776923810:RT=1776923810:S=AA-AfjZVAjozTVuJExQlQ5cGQlwR',
    '_ss_pp_id': 'd9508ee7e9b8030e5c51774393508847',
    'AviviD_session_id': '1776923810639',
    '_gcl_au': '1.1.374889474.1776923811',
    '_ht_hi': '1',
    'AviviD_refresh_uuid_status': '2',
    '_ht_47b240': '1',
    'AviviD_already_exist': '1',
    'show_avivid_native_subscribe': '2',
    'cookieConsent': 'true',
    'cookieConsent': 'true',
    '_ht_f3244e': '1',
    'FCCDCF': '%5Bnull%2Cnull%2Cnull%2Cnull%2Cnull%2Cnull%
200031341.1774422308993; AviviD_uuid=b1096f9b-0b8a-4fcf-b55a-fe98fd32666c; webuserid=0bd73413-5f7c-4803-329b-ec4883166633; AviviD_loadscript_log=1; AviviD_uuid=b1096f9b-0b8a-4fcf-b55a-fe98fd32666c; uuid=b1096f9b-0b8a-4fcf-b55a-fe98fd32666c; __gads=ID=c947f2a54e7c9261:T=1776923810:RT=1776923810:S=ALNI_MayLFCRtpwJFNhN_Mqh7_mCDXIDoA; __gpi=UID=000013e11a4a1c9e:T=1776923810:RT=1776923810:S=ALNI_MZ6mDNPWHOxOvUlcv0ia2p8p50EaA; __eoi=ID=d94c2f2afa995ab0:T=1776923810:RT=1776923810:S=AA-AfjZVAjozTVuJExQlQ5cGQlwR; _ss_pp_id=d9508ee7e9b8030e5c51774393508847; AviviD_session_id=1776923810639; _gcl_au=1.1.374889474.1776923811; _ht_hi=1; AviviD_refresh_uuid_status=2; _ht_47b240=1; AviviD_already_exist=1; show_avivid_native_subscribe=2; cookieConsent=true; cookieConsent=true; _ht_f3244e=1; FCCDCF=%5Bnull%2Cnull%2Cnull%2Cnull%2Cnull%2Cnull%2C%5B%5B32%2C%22%5B%5C%2260b09720-ac8c-4c7d-9730-e1db3e564aca%5C%22%2C%5B1776923803%2C872000000%5D%5D%22%5D%5D%5D; _ga=GA1.1.641616063.1776923804; _td=b7324bf7-0c21-42c9-b02c-2bce178f9de8; FCNEC=%5B%5B%22AKsRol8eWDsoU39ih8WQu65GMGxleVpkt2hANmM-J90A7s7eXUpatUFiCZBLOkicXgQsxuw4YxUDwECW1JxtqCsTKbuwQQ0oe7EFT8SLeYv0Pghq6k9nKtm49PaU_ZLTFOhGCd5KgRB_x8A5f6-kAnnEvBiGLo6wEQ%3D%3D%22%5D%5D; _ga_B7QHK7HLYB=GS2.1.s1776923803$o1$g1$t1776924054$j60$l0$h0',
}

params = {
    'q': 'trail',
    'act': 'detail',
    'id': '431',
}

response = requests.get('https://hiking.biji.co/index.php', params=params, cookies=cookies, headers=headers)

# print(response.status_code)
# print('-----')
# print(response.encoding)
# print('-----')
# print(response.headers)
# print('-----')
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="x-dns-prefetch-control" content="on">
#         <meta name="viewport" content="width=device-width, height=device-height, user-scalable=1">
#                 <meta name="dailymotion-domain-verification" content="dmg4s90bnv71te1dt">
#         <title>雪山主東峰步道 - 健行筆記</title>
#         <meta name="description" content="雪山主峰與東峰位於台中市和平區與苗栗泰安鄉的交界，由於鄰近中橫公路、開發較早、路徑清楚、指標和山莊等設施完善，因此在攀登雪山主峰的眾多路線之中，這條沿著東支稜上行、里程最短、難度最低的「雪東線」成為熱門的大眾化高山路線。雪山東峰矗立在...">
# <meta name="image" content="https://cdntwrunning.biji.co/600_e2cbc2dee68b0f261378d30f9cac8708d9075304b1811e072094713cad1e3ab9.jpg">
# <meta itemprop="name" content="雪山主東峰步道"/>
# <meta itemprop="description" content="雪山主峰與東峰位於台中市和平區與苗栗泰安鄉的交界，由於鄰近中橫公路、開發較早、路徑清楚、指標和山莊等設施完善，因此在攀登雪山主峰的眾多路線之中，這條沿著東支稜上行、里程最短、難度最低的「雪東線」成為熱門的大眾化高山路線。雪山東峰矗立在..."/>
# ...
