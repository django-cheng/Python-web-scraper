# %%
import requests
import os
from dotenv import load_dotenv
import pprint

# 1. 環境變數設定
load_dotenv()
AUTHORIZATION = os.getenv("AUTHORIZATION")
# /v1/rest/datastore/F-C0032-001
#三十六小時天氣預報
url = 'https://opendata.cwa.gov.tw/api/v1/rest/datastore/F-C0032-001'
params = {
    'Authorization': AUTHORIZATION,
    'format': 'JSON'
}

response = requests.get(url, params=params)
data = response.json()
#print(data)

pprint.pprint(data)
# Out:
# {'records': {'datasetDescription': '三十六小時天氣預報',
#              'location': [{'locationName': '嘉義縣',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '晴時多雲',
#                                                                        'parameterValue': '2'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '多雲短暫陣雨或雷雨',
#                                                                        'parameterValue': '15'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '40',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '40',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '28',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '23',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '23',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '30',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '28',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '27',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '新北市',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '多雲時陰短暫陣雨',
#                                                                        'parameterValue': '9'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '60',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '100',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '100',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '26',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '30',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '26',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '22',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '嘉義市',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '晴時多雲',
#                                                                        'parameterValue': '2'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '多雲短暫陣雨或雷雨',
#                                                                        'parameterValue': '15'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '40',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '40',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '28',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '22',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '22',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '31',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '28',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '27',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '新竹縣',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨',
#                                                                        'parameterValue': '11'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '30',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '100',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '80',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '26',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '29',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '26',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '23',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '新竹市',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '多雲時陰短暫陣雨',
#                                                                        'parameterValue': '9'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '30',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '100',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '80',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '26',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '29',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '26',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '23',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '臺北市',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '多雲時陰短暫陣雨',
#                                                                        'parameterValue': '9'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '50',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '100',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '90',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '27',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '20',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '31',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '27',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '22',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '臺南市',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '晴時多雲',
# ...
#                                                                        'parameterValue': '9'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '30',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '70',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '50',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '28',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '23',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '23',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適至悶熱'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '舒適'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '31',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '28',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '25',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]},
#                           {'locationName': '連江縣',
#                            'weatherElement': [{'elementName': 'Wx',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨',
#                                                                        'parameterValue': '11'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '陰短暫陣雨或雷雨',
#                                                                        'parameterValue': '18'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'PoP',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '80',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '90',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '30',
#                                                                        'parameterUnit': '百分比'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MinT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '19',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '17',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '17',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'CI',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '稍有寒意至舒適'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '稍有寒意'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '稍有寒意'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]},
#                                               {'elementName': 'MaxT',
#                                                'time': [{'endTime': '2026-04-23 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '21',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '12:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '06:00:00',
#                                                          'parameter': {'parameterName': '19',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-23 '
#                                                                       '18:00:00'},
#                                                         {'endTime': '2026-04-24 '
#                                                                     '18:00:00',
#                                                          'parameter': {'parameterName': '19',
#                                                                        'parameterUnit': 'C'},
#                                                          'startTime': '2026-04-24 '
#                                                                       '06:00:00'}]}]}]},
#  'result': {'fields': [{'id': 'datasetDescription', 'type': 'String'},
#                        {'id': 'locationName', 'type': 'String'},
#                        {'id': 'parameterName', 'type': 'String'},
#                        {'id': 'parameterValue', 'type': 'String'},
#                        {'id': 'parameterUnit', 'type': 'String'},
#                        {'id': 'startTime', 'type': 'Timestamp'},
#                        {'id': 'endTime', 'type': 'Timestamp'}],
#             'resource_id': 'F-C0032-001'},
#  'success': 'true'}

# %%
import requests
import os
from dotenv import load_dotenv
import pprint

# 1. 環境變數設定
load_dotenv()
AUTHORIZATION = os.getenv("AUTHORIZATION")
# /v1/rest/datastore/O-A0001-001
# 2. 定義參數
# 注意：dataid 是路徑的一部分，不放入 params
# 氣象觀測站-全測站逐時氣象資料
dataid = 'O-A0001-001' 

# 3. 準備 Query Parameters (查詢參數)
# 這些參數會被 requests 自動轉換為 url?key=value 的形式
# 'timeFrom': '2023-04-01T00:00:00',
# 'timeTo' : '2023-04-05T00:00:00'
# 'StationId': 'C0D550',  # 雪霸為我們指定測站
params = {
    'Authorization': AUTHORIZATION,
    'timeFrom': '2023-04-01T00:00:00',
    'timeTo' : '2023-04-05T00:00:00',
    'StationId': 'C0D550'
}

# 4. 組合 URL 並發送請求
# 修正 Base URL 為 /api/v1/rest/datastore
url = "https://opendata.cwa.gov.tw/api/v1/rest/datastore/O-A0001-001"


# 發送 GET 請求
res = requests.get(url, params=params)
obj = res.json()

#print(data)

# --- 觀察回應 ---
pprint.pprint(obj)
# Out:
# {'records': {'Station': [{'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                            'degrees',
#                                                        'CoordinateName': 'TWD67',
#                                                        'StationLatitude': '24.528722',
#                                                        'StationLongitude': '121.107917'},
#                                                       {'CoordinateFormat': 'decimal '
#                                                                            'degrees',
#                                                        'CoordinateName': 'WGS84',
#                                                        'StationLatitude': '24.526972',
#                                                        'StationLongitude': '121.116050'}],
#                                       'CountyCode': '10004',
#                                       'CountyName': '新竹縣',
#                                       'StationAltitude': '1956.0',
#                                       'TownCode': '10004130',
#                                       'TownName': '五峰鄉'},
#                           'ObsTime': {'DateTime': '2026-04-23T15:00:00+08:00'},
#                           'StationId': 'C0D550',
#                           'StationName': '雪霸',
#                           'WeatherElement': {'AirPressure': '807.5',
#                                              'AirTemperature': '18.4',
#                                              'DailyExtreme': {'DailyHigh': {'TemperatureInfo': {'AirTemperature': '22.2',
#                                                                                                 'Occurred_at': {'DateTime': '2026-04-23T12:10:00+08:00'}}},
#                                                               'DailyLow': {'TemperatureInfo': {'AirTemperature': '14.6',
#                                                                                                'Occurred_at': {'DateTime': '2026-04-23T03:50:00+08:00'}}}},
#                                              'GustInfo': {'Occurred_at': {'DateTime': '2026-04-23T14:57:00+08:00',
#                                                                           'WindDirection': '252.0'},
#                                                           'PeakGustSpeed': '6.2'},
#                                              'Now': {'Precipitation': '0.0'},
#                                              'RelativeHumidity': '69',
#                                              'Weather': '多雲',
#                                              'WindDirection': '165.0',
#                                              'WindSpeed': '0.3'}}]},
#  'result': {'fields': [{'id': 'StationName', 'type': 'String'},
#                        {'id': 'StationId', 'type': 'String'},
#                        {'id': 'CoordinateName', 'type': 'String'},
#                        {'id': 'CoordinateFormat', 'type': 'String'},
#                        {'id': 'StationLatitude', 'type': 'String'},
#                        {'id': 'StationLongitude', 'type': 'String'},
#                        {'id': 'StationAltitude', 'type': 'String'},
#                        {'id': 'CountyName', 'type': 'String'},
#                        {'id': 'TownName', 'type': 'String'},
#                        {'id': 'CountyCode', 'type': 'String'},
#                        {'id': 'TownCode', 'type': 'String'},
#                        {'id': 'Weather', 'type': 'String'},
#                        {'id': 'Precipitation', 'type': 'String'},
#                        {'id': 'WindDirection', 'type': 'String'},
#                        {'id': 'WindSpeed', 'type': 'String'},
#                        {'id': 'AirTemperature', 'type': 'String'},
#                        {'id': 'RelativeHumidity', 'type': 'String'},
#                        {'id': 'AirPressure', 'type': 'String'},
#                        {'id': 'UVIndex', 'type': 'String'},
#                        {'id': 'PeakGustSpeed', 'type': 'String'},
#                        {'id': 'DateTime', 'type': 'DateTime'}],
#             'resource_id': 'O-A0001-001'},
#  'success': 'true'}

# %%
import os
import requests
import pprint
from datetime import datetime, timedelta
from dotenv import load_dotenv

def fetch_cwa_sea_condition(station_id: str) -> dict:
    """
    獲取中央氣象署 48 小時內的海象監測資料。
    
    Args:
        station_id (str): 測站代碼 (例如龜山島為 "46708A")
        
    Returns:
        dict: 結構化的 JSON 資料。若請求失敗則回傳空字典。
    """
    # 1. 環境變數設定與驗證
    load_dotenv()
    authorization = os.getenv("AUTHORIZATION")
    if not authorization:
        raise ValueError("環境變數 AUTHORIZATION 未設定，請檢查 .env 檔案。")

    # 2. 定義 API 端點與路由
    dataid = 'O-B0075-001' 
    base_url = "https://opendata.cwa.gov.tw/api/v1/rest/datastore"
    url = f"{base_url}/{dataid}"

    # 3. 動態計算時間區段 (嚴格遵守 48 小時限制)
    now = datetime.now()
    past_48h = now - timedelta(hours=48)
    
    # 轉換為 ISO 8601 格式字串
    time_to_str = now.strftime('%Y-%m-%dT%H:%M:%S')
    time_from_str = past_48h.strftime('%Y-%m-%dT%H:%M:%S')

    # 4. 準備查詢參數
    params = {
        'Authorization': authorization,
        'StationID': station_id,
        'timeFrom': time_from_str,
        'timeTo': time_to_str
    }

    # 5. 發送 HTTP 請求與異常處理
    try:
        # 設定 timeout，避免伺服器無回應導致程式永久卡死
        response = requests.get(url, params=params, timeout=10)
        
        # 解析並回傳 JSON 資料
        return response.json()

# ==========================================
# 主程式執行區塊
# ==========================================
if __name__ == "__main__":
    # 龜山島測站
    target_station = "46708A"
    
    print(f"開始獲取測站 {target_station} 近 48 小時海象資料...")
    sea_data = fetch_cwa_sea_condition(station_id=target_station)
    
    if sea_data:
        print("資料獲取成功：")
        pprint.pprint(sea_data)
    else:
        print("未能獲取有效資料，請檢查日誌。")
# Out:
# {"Success":"true","Result":{"ResourceId":"O-B0075-001","Fields":[{"Id":"StationID","Type":"String"},{"Id":"DataTime","Type":"Timestamp"},{"Id":"TideHeight","Type":"String"},{"Id":"TideLevel","Type":"String"},{"Id":"WaveHeight","Type":"String"},{"Id":"WaveDirection","Type":"String"},{"Id":"WaveDirectionDescription","Type":"String"},{"Id":"WavePeriod","Type":"String"},{"Id":"SeaTemperature","Type":"String"},{"Id":"StationPressure","Type":"String"},{"Id":"WindSpeed","Type":"String"},{"Id":"WindScale","Type":"String"},{"Id":"WindDirection","Type":"String"},{"Id":"WindDirectionDescription","Type":"String"},{"Id":"MaximumWindSpeed","Type":"String"},{"Id":"MaximumWindScale","Type":"String"},{"Id":"LayerNumber","Type":"Integer"},{"Id":"CurrentDirection","Type":"String"},{"Id":"CurrentDirectionDescription","Type":"String"},{"Id":"CurrentSpeed","Type":"String"},{"Id":"CurrentSpeedInKnots","Type":"String"}]},"Records":{"SeaSurfaceObs":{"Location":[{"Station":{"StationID":"46708A"},"StationObsTimes":{"StationObsTime":[{"DateTime":"2026-04-19T19:00:00+08:00","WeatherElements":{"TideHeight":"None","TideLevel":"-","WaveHeight":"0.9","WaveDirection":"90.0","WaveDirectionDescription":"E","WavePeriod":"9.0","SeaTemperature":"25.0","Temperature":"23.2","StationPressure":"1014.2","PrimaryAnemometer":{"WindSpeed":"None","WindScale":"None","WindDirection":"None","WindDirectionDescription":"None","MaximumWindSpeed":"None","MaximumWindScale":"None"},"SeaCurrents":{"Layer":[{"LayerNumber":"1","CurrentDirection":"265","CurrentDirectionDescription":"W","CurrentSpeed":"0.26","CurrentSpeedInKnots":"0.51"}]}}},{"DateTime":"2026-04-19T12:00:00+08:00","WeatherElements":{"TideHeight":"None","TideLevel":"-","WaveHeight":"0.8","WaveDirection":"56.0","WaveDirectionDescription":"NE","WavePeriod":"7.1","SeaTemperature":"24.9","Temperature":"23.3","StationPressure":"1014.3","PrimaryAnemometer":{"WindSpeed":"6.7","WindScale":"4","WindDirection":"58.0","WindDirectionDescription":"ENE","MaximumWindSpeed":"8.4","MaximumWindScale":"5"},"SeaCurrents":{"Layer":[{"LayerNumber":"1","CurrentDirection":"184","CurrentDirectionDescription":"S","CurrentSpeed":"0.11","CurrentSpeedInKnots":"0.21"}]}}},{"DateTime":"2026-04-19T05:00:00+08:00","WeatherElements":{"TideHeight":"None","TideLevel":"-","WaveHeight":"0.9","WaveDirection":"213.0","WaveDirectionDescription":"SSW","WavePeriod":"6.0","SeaTemperature":"25.0","Temperature":"22.4","StationPressure":"1013.1","PrimaryAnemometer":{"WindSpeed":"2.9","WindScale":"2","WindDirection":"35.0","WindDirectionDescription":"NE","MaximumWindSpeed":"4.3","MaximumWindScale":"3"},"SeaCurrents":{"Layer":[{"LayerNumber":"1","CurrentDirection":"61","CurrentDirectionDescription":"ENE","CurrentSpeed":"0.06","CurrentSpeedInKnots":"0.12"}]}}},{"DateTime":"2026-04-18T22:00:00+08:00","WeatherElements":{"TideHeight":"None","TideLevel":"-","WaveHeight":"1.0","WaveDirection":"146.0","WaveDirectionDescription":"SE","WavePeriod":"6.8","SeaTemperature":"25.0","Temperature":"22.6","StationPressure":"1014.6","PrimaryAnemometer":{"WindSpeed":"4.5","WindScale":"3","WindDirection":"17.0","WindDirectionDescription":"NNE","MaximumWindSpeed":"6.3","MaximumWindScale":"4"},"SeaCurrents":{"Layer":[{"LayerNumber":"1","CurrentDirection":"111","CurrentDirectionDescription":"ESE","CurrentSpeed":"0.13","CurrentSpeedInKnots":"0.25"}]}}},{"DateTime":"2026-04-18T15:00:00+08:00","WeatherElements":{"TideHeight":"None","TideLevel":"-","WaveHeight":"1.2","WaveDirection":"180.0","WaveDirectionDescription":"S","WavePeriod":"5.7","SeaTemperature":"25.7","Temperature":"23.6","StationPressure":"1011.8","PrimaryAnemometer":{"WindSpeed":"8.6","WindScale":"5","WindDirection":"29.0","WindDirectionDescription":"NNE","MaximumWindSpeed":"11.1","MaximumWindScale":"6"},"SeaCurrents":{"Layer":[{"LayerNumber":"1","CurrentDirection":"148","CurrentDirectionDescription":"SSE","CurrentSpeed":"0.51","CurrentSpeedInKnots":"0.99"}]}}},{"DateTime":"2026-04-19T07:00:00+08:00","WeatherElements":{"TideHeight": ...
# {'Records': {'SeaSurfaceObs': {'Location': [{'Station': {'StationID': '46708A'},
#                                              'StationObsTimes': {'StationObsTime': [{'DateTime': '2026-04-19T19:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': 'None',
#                                                                                                                                'MaximumWindSpeed': 'None',
#                                                                                                                                'WindDirection': 'None',
#                                                                                                                                'WindDirectionDescription': 'None',
#                                                                                                                                'WindScale': 'None',
#                                                                                                                                'WindSpeed': 'None'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '265',
#                                                                                                                                     'CurrentDirectionDescription': 'W',
#                                                                                                                                     'CurrentSpeed': '0.26',
#                                                                                                                                     'CurrentSpeedInKnots': '0.51',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.0',
#                                                                                                          'StationPressure': '1014.2',
#                                                                                                          'Temperature': '23.2',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '90.0',
#                                                                                                          'WaveDirectionDescription': 'E',
#                                                                                                          'WaveHeight': '0.9',
#                                                                                                          'WavePeriod': '9.0'}},
#                                                                                     {'DateTime': '2026-04-19T12:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '5',
#                                                                                                                                'MaximumWindSpeed': '8.4',
#                                                                                                                                'WindDirection': '58.0',
#                                                                                                                                'WindDirectionDescription': 'ENE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '6.7'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '184',
#                                                                                                                                     'CurrentDirectionDescription': 'S',
#                                                                                                                                     'CurrentSpeed': '0.11',
#                                                                                                                                     'CurrentSpeedInKnots': '0.21',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '24.9',
#                                                                                                          'StationPressure': '1014.3',
#                                                                                                          'Temperature': '23.3',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '56.0',
#                                                                                                          'WaveDirectionDescription': 'NE',
#                                                                                                          'WaveHeight': '0.8',
#                                                                                                          'WavePeriod': '7.1'}},
#                                                                                     {'DateTime': '2026-04-19T05:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '3',
#                                                                                                                                'MaximumWindSpeed': '4.3',
#                                                                                                                                'WindDirection': '35.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '2',
#                                                                                                                                'WindSpeed': '2.9'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '61',
#                                                                                                                                     'CurrentDirectionDescription': 'ENE',
#                                                                                                                                     'CurrentSpeed': '0.06',
#                                                                                                                                     'CurrentSpeedInKnots': '0.12',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.0',
#                                                                                                          'StationPressure': '1013.1',
#                                                                                                          'Temperature': '22.4',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '213.0',
#                                                                                                          'WaveDirectionDescription': 'SSW',
#                                                                                                          'WaveHeight': '0.9',
#                                                                                                          'WavePeriod': '6.0'}},
#                                                                                     {'DateTime': '2026-04-18T22:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '4',
#                                                                                                                                'MaximumWindSpeed': '6.3',
#                                                                                                                                'WindDirection': '17.0',
#                                                                                                                                'WindDirectionDescription': 'NNE',
#                                                                                                                                'WindScale': '3',
#                                                                                                                                'WindSpeed': '4.5'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '111',
#                                                                                                                                     'CurrentDirectionDescription': 'ESE',
#                                                                                                                                     'CurrentSpeed': '0.13',
#                                                                                                                                     'CurrentSpeedInKnots': '0.25',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.0',
#                                                                                                          'StationPressure': '1014.6',
#                                                                                                          'Temperature': '22.6',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '146.0',
#                                                                                                          'WaveDirectionDescription': 'SE',
#                                                                                                          'WaveHeight': '1.0',
#                                                                                                          'WavePeriod': '6.8'}},
#                                                                                     {'DateTime': '2026-04-18T15:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '6',
#                                                                                                                                'MaximumWindSpeed': '11.1',
#                                                                                                                                'WindDirection': '29.0',
#                                                                                                                                'WindDirectionDescription': 'NNE',
#                                                                                                                                'WindScale': '5',
#                                                                                                                                'WindSpeed': '8.6'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '148',
#                                                                                                                                     'CurrentDirectionDescription': 'SSE',
#                                                                                                                                     'CurrentSpeed': '0.51',
#                                                                                                                                     'CurrentSpeedInKnots': '0.99',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.7',
#                                                                                                          'StationPressure': '1011.8',
#                                                                                                          'Temperature': '23.6',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '180.0',
#                                                                                                          'WaveDirectionDescription': 'S',
#                                                                                                          'WaveHeight': '1.2',
#                                                                                                          'WavePeriod': '5.7'}},
#                                                                                     {'DateTime': '2026-04-19T07:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '3',
#                                                                                                                                'MaximumWindSpeed': '5.1',
#                                                                                                                                'WindDirection': '41.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '2',
#                                                                                                                                'WindSpeed': '3.1'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '351',
#                                                                                                                                     'CurrentDirectionDescription': 'N',
#                                                                                                                                     'CurrentSpeed': '0.28',
#                                                                                                                                     'CurrentSpeedInKnots': '0.54',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '24.6',
#                                                                                                          'StationPressure': '1013.9',
#                                                                                                          'Temperature': '22.8',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '168.0',
#                                                                                                          'WaveDirectionDescription': 'SSE',
#                                                                                                          'WaveHeight': '0.8',
#                                                                                                          'WavePeriod': '6.7'}},
#                                                                                     {'DateTime': '2026-04-19T00:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '4',
#                                                                                                                                'MaximumWindSpeed': '6.7',
#                                                                                                                                'WindDirection': '19.0',
#                                                                                                                                'WindDirectionDescription': 'NNE',
#                                                                                                                                'WindScale': '3',
#                                                                                                                                'WindSpeed': '5.1'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '157',
#                                                                                                                                     'CurrentDirectionDescription': 'SSE',
#                                                                                                                                     'CurrentSpeed': '0.13',
#                                                                                                                                     'CurrentSpeedInKnots': '0.25',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '24.7',
#                                                                                                          'StationPressure': '1014.5',
#                                                                                                          'Temperature': '22.6',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '191.0',
#                                                                                                          'WaveDirectionDescription': 'S',
#                                                                                                          'WaveHeight': '0.8',
#                                                                                                          'WavePeriod': '8.2'}},
#                                                                                     {'DateTime': '2026-04-18T17:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '6',
#                                                                                                                                'MaximumWindSpeed': '11.6',
#                                                                                                                                'WindDirection': '45.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '5',
#                                                                                                                                'WindSpeed': '8.8'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '279',
#                                                                                                                                     'CurrentDirectionDescription': 'W',
#                                                                                                                                     'CurrentSpeed': '0.11',
#                                                                                                                                     'CurrentSpeedInKnots': '0.21',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.6',
#                                                                                                          'StationPressure': '1012.1',
#                                                                                                          'Temperature': '22.8',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '213.0',
#                                                                                                          'WaveDirectionDescription': 'SSW',
#                                                                                                          'WaveHeight': '1.2',
#                                                                                                          'WavePeriod': '5.7'}},
#                                                                                     {'DateTime': '2026-04-19T21:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '2',
#                                                                                                                                'MaximumWindSpeed': '3.3',
#                                                                                                                                'WindDirection': '250.0',
#                                                                                                                                'WindDirectionDescription': 'WSW',
#                                                                                                                                'WindScale': '2',
#                                                                                                                                'WindSpeed': '2.2'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '3',
#                                                                                                                                     'CurrentDirectionDescription': 'N',
#                                                                                                                                     'CurrentSpeed': '0.56',
#                                                                                                                                     'CurrentSpeedInKnots': '1.09',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '26.0',
#                                                                                                          'StationPressure': '1014.9',
#                                                                                                          'Temperature': '23.6',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '0.0',
#                                                                                                          'WaveDirectionDescription': 'N',
#                                                                                                          'WaveHeight': '0.9',
#                                                                                                          'WavePeriod': '9.0'}},
#                                                                                     {'DateTime': '2026-04-19T14:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '4',
#                                                                                                                                'MaximumWindSpeed': '7.6',
#                                                                                                                                'WindDirection': '60.0',
#                                                                                                                                'WindDirectionDescription': 'ENE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '6.0'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '3',
#                                                                                                                                     'CurrentDirectionDescription': 'N',
#                                                                                                                                     'CurrentSpeed': '0.18',
#                                                                                                                                     'CurrentSpeedInKnots': '0.35',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.2',
#                                                                                                          'StationPressure': '1013.4',
#                                                                                                          'Temperature': '23.2',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '180.0',
#                                                                                                          'WaveDirectionDescription': 'S',
#                                                                                                          'WaveHeight': '0.8',
#                                                                                                          'WavePeriod': '5.9'}},
#                                                                                     {'DateTime': '2026-04-18T18:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '5',
#                                                                                                                                'MaximumWindSpeed': '10.6',
#                                                                                                                                'WindDirection': '42.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '5',
#                                                                                                                                'WindSpeed': '8.3'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '316',
#                                                                                                                                     'CurrentDirectionDescription': 'NW',
#                                                                                                                                     'CurrentSpeed': '0.37',
#                                                                                                                                     'CurrentSpeedInKnots': '0.72',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.2',
#                                                                                                          'StationPressure': '1012.6',
#                                                                                                          'Temperature': '22.7',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '22.0',
#                                                                                                          'WaveDirectionDescription': 'NNE',
#                                                                                                          'WaveHeight': '1.0',
#                                                                                                          'WavePeriod': '4.9'}},
#                                                                                     {'DateTime': '2026-04-18T11:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': 'None',
#                                                                                                                                'MaximumWindSpeed': 'None',
#                                                                                                                                'WindDirection': 'None',
#                                                                                                                                'WindDirectionDescription': 'None',
#                                                                                                                                'WindScale': 'None',
#                                                                                                                                'WindSpeed': 'None'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': 'None',
#                                                                                                                                     'CurrentDirectionDescription': 'None',
#                                                                                                                                     'CurrentSpeed': 'None',
#                                                                                                                                     'CurrentSpeedInKnots': 'None',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': 'None',
#                                                                                                          'StationPressure': 'None',
#                                                                                                          'Temperature': 'None',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': 'None',
#                                                                                                          'WaveDirectionDescription': 'None',
#                                                                                                          'WaveHeight': 'None',
#                                                                                                          'WavePeriod': 'None'}},
#                                                                                     {'DateTime': '2026-04-18T20:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '5',
#                                                                                                                                'MaximumWindSpeed': '8.2',
#                                                                                                                                'WindDirection': '35.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '6.3'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '1',
#                                                                                                                                     'CurrentDirectionDescription': 'N',
#                                                                                                                                     'CurrentSpeed': '0.56',
#                                                                                                                                     'CurrentSpeedInKnots': '1.09',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '24.7',
#                                                                                                          'StationPressure': '1014.0',
#                                                                                                          'Temperature': '22.7',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '168.0',
#                                                                                                          'WaveDirectionDescription': 'SSE',
#                                                                                                          'WaveHeight': '1.1',
#                                                                                                          'WavePeriod': '6.4'}},
#                                                                                     {'DateTime': '2026-04-18T13:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '4',
#                                                                                                                                'MaximumWindSpeed': '7.9',
#                                                                                                                                'WindDirection': '43.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '5.9'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '52',
#                                                                                                                                     'CurrentDirectionDescription': 'NE',
#                                                                                                                                     'CurrentSpeed': '0.47',
#                                                                                                                                     'CurrentSpeedInKnots': '0.91',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.6',
#                                                                                                          'StationPressure': '1012.4',
#                                                                                                          'Temperature': '24.0',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '202.0',
#                                                                                                          'WaveDirectionDescription': 'SSW',
#                                                                                                          'WaveHeight': '0.9',
#                                                                                                          'WavePeriod': '5.4'}},
#                                                                                     {'DateTime': '2026-04-19T17:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '3',
#                                                                                                                                'MaximumWindSpeed': '4.6',
#                                                                                                                                'WindDirection': '54.0',
#                                                                                                                                'WindDirectionDescription': 'NE',
#                                                                                                                                'WindScale': '2',
#                                                                                                                                'WindSpeed': '3.3'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '215',
#                                                                                                                                     'CurrentDirectionDescription': 'SW',
#                                                                                                                                     'CurrentSpeed': '0.22',
#                                                                                                                                     'CurrentSpeedInKnots': '0.43',
# ...
#                                                                                                                                'WindDirectionDescription': 'ENE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '7.1'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '254',
#                                                                                                                                     'CurrentDirectionDescription': 'WSW',
#                                                                                                                                     'CurrentSpeed': '0.09',
#                                                                                                                                     'CurrentSpeedInKnots': '0.17',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.0',
#                                                                                                          'StationPressure': '1014.6',
#                                                                                                          'Temperature': '23.2',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '56.0',
#                                                                                                          'WaveDirectionDescription': 'NE',
#                                                                                                          'WaveHeight': '0.8',
#                                                                                                          'WavePeriod': '7.2'}},
#                                                                                     {'DateTime': '2026-04-19T04:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '4',
#                                                                                                                                'MaximumWindSpeed': '7.0',
#                                                                                                                                'WindDirection': '7.0',
#                                                                                                                                'WindDirectionDescription': 'N',
#                                                                                                                                'WindScale': '3',
#                                                                                                                                'WindSpeed': '4.8'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '93',
#                                                                                                                                     'CurrentDirectionDescription': 'E',
#                                                                                                                                     'CurrentSpeed': '0.33',
#                                                                                                                                     'CurrentSpeedInKnots': '0.64',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.1',
#                                                                                                          'StationPressure': '1012.8',
#                                                                                                          'Temperature': '22.4',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '146.0',
#                                                                                                          'WaveDirectionDescription': 'SE',
#                                                                                                          'WaveHeight': '0.9',
#                                                                                                          'WavePeriod': '6.2'}},
#                                                                                     {'DateTime': '2026-04-18T21:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '4',
#                                                                                                                                'MaximumWindSpeed': '7.4',
#                                                                                                                                'WindDirection': '23.0',
#                                                                                                                                'WindDirectionDescription': 'NNE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '5.5'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '25',
#                                                                                                                                     'CurrentDirectionDescription': 'NNE',
#                                                                                                                                     'CurrentSpeed': '0.19',
#                                                                                                                                     'CurrentSpeedInKnots': '0.37',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.1',
#                                                                                                          'StationPressure': '1014.3',
#                                                                                                          'Temperature': '22.7',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '168.0',
#                                                                                                          'WaveDirectionDescription': 'SSE',
#                                                                                                          'WaveHeight': '0.9',
#                                                                                                          'WavePeriod': '5.6'}},
#                                                                                     {'DateTime': '2026-04-18T14:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '5',
#                                                                                                                                'MaximumWindSpeed': '8.6',
#                                                                                                                                'WindDirection': '31.0',
#                                                                                                                                'WindDirectionDescription': 'NNE',
#                                                                                                                                'WindScale': '4',
#                                                                                                                                'WindSpeed': '6.5'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '84',
#                                                                                                                                     'CurrentDirectionDescription': 'E',
#                                                                                                                                     'CurrentSpeed': '0.39',
#                                                                                                                                     'CurrentSpeedInKnots': '0.76',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '25.5',
#                                                                                                          'StationPressure': '1011.9',
#                                                                                                          'Temperature': '24.2',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '135.0',
#                                                                                                          'WaveDirectionDescription': 'SE',
#                                                                                                          'WaveHeight': '1.3',
#                                                                                                          'WavePeriod': '7.4'}},
#                                                                                     {'DateTime': '2026-04-19T18:00:00+08:00',
#                                                                                      'WeatherElements': {'PrimaryAnemometer': {'MaximumWindScale': '2',
#                                                                                                                                'MaximumWindSpeed': '3.3',
#                                                                                                                                'WindDirection': '67.0',
#                                                                                                                                'WindDirectionDescription': 'ENE',
#                                                                                                                                'WindScale': '2',
#                                                                                                                                'WindSpeed': '2.3'},
#                                                                                                          'SeaCurrents': {'Layer': [{'CurrentDirection': '289',
#                                                                                                                                     'CurrentDirectionDescription': 'WNW',
#                                                                                                                                     'CurrentSpeed': '0.48',
#                                                                                                                                     'CurrentSpeedInKnots': '0.93',
#                                                                                                                                     'LayerNumber': '1'}]},
#                                                                                                          'SeaTemperature': '24.8',
#                                                                                                          'StationPressure': '1013.4',
#                                                                                                          'Temperature': '23.2',
#                                                                                                          'TideHeight': 'None',
#                                                                                                          'TideLevel': '-',
#                                                                                                          'WaveDirection': '101.0',
#                                                                                                          'WaveDirectionDescription': 'E',
#                                                                                                          'WaveHeight': '0.5',
#                                                                                                          'WavePeriod': '6.2'}}]}}]}},
#  'Result': {'Fields': [{'Id': 'StationID', 'Type': 'String'},
#                        {'Id': 'DataTime', 'Type': 'Timestamp'},
#                        {'Id': 'TideHeight', 'Type': 'String'},
#                        {'Id': 'TideLevel', 'Type': 'String'},
#                        {'Id': 'WaveHeight', 'Type': 'String'},
#                        {'Id': 'WaveDirection', 'Type': 'String'},
#                        {'Id': 'WaveDirectionDescription', 'Type': 'String'},
#                        {'Id': 'WavePeriod', 'Type': 'String'},
#                        {'Id': 'SeaTemperature', 'Type': 'String'},
#                        {'Id': 'StationPressure', 'Type': 'String'},
#                        {'Id': 'WindSpeed', 'Type': 'String'},
#                        {'Id': 'WindScale', 'Type': 'String'},
#                        {'Id': 'WindDirection', 'Type': 'String'},
#                        {'Id': 'WindDirectionDescription', 'Type': 'String'},
#                        {'Id': 'MaximumWindSpeed', 'Type': 'String'},
#                        {'Id': 'MaximumWindScale', 'Type': 'String'},
#                        {'Id': 'LayerNumber', 'Type': 'Integer'},
#                        {'Id': 'CurrentDirection', 'Type': 'String'},
#                        {'Id': 'CurrentDirectionDescription', 'Type': 'String'},
#                        {'Id': 'CurrentSpeed', 'Type': 'String'},
#                        {'Id': 'CurrentSpeedInKnots', 'Type': 'String'}],
#             'ResourceId': 'O-B0075-001'},
#  'Success': 'true'}
